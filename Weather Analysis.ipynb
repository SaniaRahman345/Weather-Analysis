# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Talal\\Downloads\\archive (2)\\weatherHistory.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.shape
# Out:
# (96453, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
df.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
df.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
df['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# # All Unique Wind Speed (km/h) in data

# %%
df.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
df['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
df['Wind Speed (km/h)'] = df['Wind Speed (km/h)'].astype(int)

# %%
df['Wind Speed (km/h)'].dtype
# Out:
# dtype('int32')

# %%
df['Wind Speed (km/h)'].unique()
# Out:
# array([14,  3, 11, 13, 12, 17, 19, 21, 20, 15, 10,  8,  7,  4,  6, 16, 22,
#        23, 28, 26, 25, 18,  9,  0, 27, 30, 32, 29,  2,  5,  1, 24, 33, 36,
#        31, 45, 34, 39, 42, 44, 43, 37, 38, 35, 41, 40, 47, 46, 49, 53, 63,
#        52, 50, 55, 48, 54, 51])

# %% [markdown]
# # when Weather is exactly clear

# %%
df.Summary.value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
df[df.Summary == 'Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
df.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# # Wind Speed was exactly 4km/h

# %%
df[df['Wind Speed (km/h)'] == 4]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 21     2006-04-01 21:00:00.000 +0200  Mostly Cloudy        rain
# 109    2006-04-13 13:00:00.000 +0200       Overcast        rain
# 126    2006-04-14 06:00:00.000 +0200          Foggy        rain
# 212    2006-04-17 20:00:00.000 +0200  Mostly Cloudy        rain
# 213    2006-04-17 21:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96341  2016-09-05 08:00:00.000 +0200       Overcast        rain
# 96364  2016-09-06 07:00:00.000 +0200  Mostly Cloudy        rain
# 96394  2016-09-07 13:00:00.000 +0200  Partly Cloudy        rain
# 96411  2016-09-08 06:00:00.000 +0200  Mostly Cloudy        rain
# 96435  2016-09-09 06:00:00.000 +0200          Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 21           11.183333                 11.183333      0.76                  4
# ...

# %% [markdown]
# # All Null Values in Data

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df['Precip Type'].isnull().sum()
# Out:
# 517

# %%
df.dropna(subset=['Precip Type'], inplace=True)

# %%
df['Precip Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Rename the Column Name 'Summary' to 'Weather Condition'

# %%
df.rename(columns = {'Summary' : 'Weather Condition'}, inplace = True)

# %%
df.head()
# Out:
#                   Formatted Date Weather Condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
# 2  2006-04-01 02:00:00.000 +0200     Mostly Cloudy        rain
# 3  2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain
# 4  2006-04-01 04:00:00.000 +0200     Mostly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89                 14
# 1         9.355556                  7.227778      0.86                 14
# 2         9.377778                  9.377778      0.89                  3
# 3         8.288889                  5.944444      0.83                 14
# 4         8.755556                  6.977778      0.83                 11
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# ...

# %% [markdown]
# # Mean Value of Visibility

# %%
df['Visibility (km)'].mean()
# Out:
# 10.36240244120785

# %% [markdown]
# # Standard Deviation of Pressure (millibars)

# %%
df['Pressure (millibars)'].std()
# Out:
# 117.27697626185551

# %% [markdown]
# # Varience of Humidity

# %%
df['Humidity'].var()
# Out:
# 0.03830793112709668

# %% [markdown]
# # When Weather  was Foggy

# %% [raw]
# # to find this we have three methods
# # 1= value_counts
# # 2= filtering
# # 3= str_contains

# %%
df.head(2)
# Out:
#                   Formatted Date Weather Condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89                 14
# 1         9.355556                  7.227778      0.86                 14
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df['Weather Condition'].value_counts()
# Out:
# Partly Cloudy                          31635
# Mostly Cloudy                          27914
# Overcast                               16516
# Clear                                  10763
# Foggy                                   7117
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
df[df['Weather Condition'] == 'Foggy'].head(50)
# Out:
#                      Formatted Date Weather Condition Precip Type  \
# 66    2006-04-11 18:00:00.000 +0200             Foggy        rain
# 67    2006-04-11 19:00:00.000 +0200             Foggy        rain
# 72    2006-04-12 00:00:00.000 +0200             Foggy        rain
# 73    2006-04-12 01:00:00.000 +0200             Foggy        rain
# 126   2006-04-14 06:00:00.000 +0200             Foggy        rain
# 222   2006-04-18 06:00:00.000 +0200             Foggy        rain
# 242   2006-04-19 02:00:00.000 +0200             Foggy        rain
# 289   2006-04-20 01:00:00.000 +0200             Foggy        rain
# 291   2006-04-20 03:00:00.000 +0200             Foggy        rain
# 292   2006-04-20 04:00:00.000 +0200             Foggy        rain
# 293   2006-04-20 05:00:00.000 +0200             Foggy        rain
# 294   2006-04-20 06:00:00.000 +0200             Foggy        rain
# 295   2006-04-20 07:00:00.000 +0200             Foggy        rain
# ...

# %% [markdown]
# # Wind speed is above 10 and Visibility is 10

# %%
(df['Wind Speed (km/h)'] > 10)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 96448    False
# 96449    False
# 96450    False
# 96451    False
# 96452    False
# Name: Wind Speed (km/h), Length: 95936, dtype: bool

# %%
df['Visibility (km)'] = df['Visibility (km)'].astype(int)

# %%
df['Visibility (km)'].dtype
# Out:
# dtype('int32')

# %%
df.head(2)
# Out:
#                   Formatted Date Weather Condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89                 14
# 1         9.355556                  7.227778      0.86                 14
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0               15         0.0               1015.13
# 1                   259.0               15         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df[(df['Wind Speed (km/h)'] > 10) & (df['Visibility (km)'] == 10 )]
# Out:
#                       Formatted Date Weather Condition Precip Type  \
# 38     2006-04-10 14:00:00.000 +0200     Mostly Cloudy        rain
# 41     2006-04-10 17:00:00.000 +0200     Mostly Cloudy        rain
# 57     2006-04-11 09:00:00.000 +0200     Partly Cloudy        rain
# 63     2006-04-11 15:00:00.000 +0200     Mostly Cloudy        rain
# 64     2006-04-11 16:00:00.000 +0200     Mostly Cloudy        rain
# ...                              ...               ...         ...
# 96037  2016-09-20 16:00:00.000 +0200     Mostly Cloudy        rain
# 96038  2016-09-20 17:00:00.000 +0200     Mostly Cloudy        rain
# 96108  2016-09-23 15:00:00.000 +0200     Partly Cloudy        rain
# 96344  2016-09-05 11:00:00.000 +0200          Overcast        rain
# 96371  2016-09-06 14:00:00.000 +0200     Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 38           21.050000                 21.050000      0.40                 26
# ...

# %% [markdown]
# # Mean Value of each column against each weather Condition

# %%
df.head(2)
# Out:
#                   Formatted Date Weather Condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89                 14
# 1         9.355556                  7.227778      0.86                 14
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0               15         0.0               1015.13
# 1                   259.0               15         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df['Weather Condition'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        Partly Cloudy
# 1        Partly Cloudy
# 2        Mostly Cloudy
# 3        Partly Cloudy
# 4        Mostly Cloudy
#              ...
# 96448    Partly Cloudy
# 96449    Partly Cloudy
# 96450    Partly Cloudy
# 96451    Partly Cloudy
# 96452    Partly Cloudy
# Name: Weather Condition, Length: 95936, dtype: object>

# %%
df.groupby('Weather Condition').mean()
# Out:
#                                      Temperature (C)  \
# Weather Condition
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.976203
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.445124
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %% [markdown]
# # Min & Max Value of each column against each weather condition

# %%
df.groupby('Weather Condition').min()
# Out:
#                                                     Formatted Date  \
# Weather Condition
# Breezy                               2006-09-17 12:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-01-22 17:00:00.000 +0100
# Breezy and Overcast                  2006-01-19 09:00:00.000 +0100
# Breezy and Partly Cloudy             2006-03-25 08:00:00.000 +0100
# Clear                                2006-01-08 01:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2012-04-12 10:00:00.000 +0200
# Dry                                  2007-07-20 10:00:00.000 +0200
# Dry and Mostly Cloudy                2012-03-18 16:00:00.000 +0100
# Dry and Partly Cloudy                2007-04-23 13:00:00.000 +0200
# Foggy                                2006-01-05 01:00:00.000 +0100
# ...

# %%
df.groupby('Weather Condition').max()
# Out:
#                                                     Formatted Date  \
# Weather Condition
# Breezy                               2016-08-05 10:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2015-02-08 17:00:00.000 +0100
# Breezy and Mostly Cloudy             2016-09-17 15:00:00.000 +0200
# Breezy and Overcast                  2016-10-04 23:00:00.000 +0200
# Breezy and Partly Cloudy             2016-08-10 19:00:00.000 +0200
# Clear                                2016-11-02 23:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# Drizzle                              2016-10-26 14:00:00.000 +0200
# Dry                                  2013-09-07 18:00:00.000 +0200
# Dry and Mostly Cloudy                2012-10-05 16:00:00.000 +0200
# Dry and Partly Cloudy                2015-08-10 12:00:00.000 +0200
# Foggy                                2016-10-17 01:00:00.000 +0200
# ...

# %% [markdown]
# # Weather iS Clear and visibility is above 40

# %%
df[(df['Weather Condition'] == 'Clear') | (df['Visibility (km)'] > 40 )]
# Out:
#                       Formatted Date Weather Condition Precip Type  \
# 223    2006-04-18 07:00:00.000 +0200             Clear        rain
# 309    2006-04-20 21:00:00.000 +0200             Clear        rain
# 337    2006-04-22 01:00:00.000 +0200             Clear        rain
# 338    2006-04-22 02:00:00.000 +0200             Clear        rain
# 357    2006-04-22 21:00:00.000 +0200             Clear        rain
# ...                              ...               ...         ...
# 96432  2016-09-09 03:00:00.000 +0200             Clear        rain
# 96433  2016-09-09 04:00:00.000 +0200             Clear        rain
# 96434  2016-09-09 05:00:00.000 +0200             Clear        rain
# 96435  2016-09-09 06:00:00.000 +0200             Clear        rain
# 96436  2016-09-09 07:00:00.000 +0200             Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 223           8.688889                  8.688889      0.93                  1
# ...

# %%
df[(df['Weather Condition'] == 'Clear') | (df['Visibility (km)'] > 40 )].head(20)
# Out:
#                     Formatted Date Weather Condition Precip Type  \
# 223  2006-04-18 07:00:00.000 +0200             Clear        rain
# 309  2006-04-20 21:00:00.000 +0200             Clear        rain
# 337  2006-04-22 01:00:00.000 +0200             Clear        rain
# 338  2006-04-22 02:00:00.000 +0200             Clear        rain
# 357  2006-04-22 21:00:00.000 +0200             Clear        rain
# 358  2006-04-22 22:00:00.000 +0200             Clear        rain
# 359  2006-04-22 23:00:00.000 +0200             Clear        rain
# 360  2006-04-23 00:00:00.000 +0200             Clear        rain
# 361  2006-04-23 01:00:00.000 +0200             Clear        rain
# 363  2006-04-23 03:00:00.000 +0200             Clear        rain
# 386  2006-04-24 02:00:00.000 +0200             Clear        rain
# 391  2006-04-24 07:00:00.000 +0200             Clear        rain
# 392  2006-04-24 08:00:00.000 +0200             Clear        rain
# ...

# %% [markdown]
# # Find ALL Instances where:

# %% [raw]
# A: Weather is clear and humidity is greater than 50
#     or
# B: Visibility is above 40

# %%
df.head(2)
# Out:
#                   Formatted Date Weather Condition Precip Type  \
# 0  2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1  2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
#
#    Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0         9.472222                  7.388889      0.89                 14
# 1         9.355556                  7.227778      0.86                 14
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0               15         0.0               1015.13
# 1                   259.0               15         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df[(df['Weather Condition'] == 'Clear') & (df['Humidity'] > 10) | (df['Visibility (km)'] > 10)]
# Out:
#                       Formatted Date Weather Condition Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200     Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200     Mostly Cloudy        rain
# ...                              ...               ...         ...
# 96448  2016-09-09 19:00:00.000 +0200     Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200     Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200     Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200     Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200     Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89                 14
# ...
